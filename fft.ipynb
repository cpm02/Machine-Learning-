# %% [markdown]
# # <center> IIIT Vadodara </center>
# ## <center> Winter 2021-22 </center>
# ## <center> CS 612, CS 652, CS/IT 308 Machine Learning </center>

# %% [markdown]
# ## Question 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft2
from numpy import linalg as la
import matplotlib.image as mpimg
import glob
from numpy import linalg as LA
import scipy.io as sio 
from mpl_toolkits import mplot3d

# %%
x=np.array([[0,1],[1,0]])
plt.imshow(x,cmap="gray")
plt.colorbar()

# %%
tra=fft2(x)
plt.imshow(abs(tra),cmap="gray")

# %%
x=np.array([np.zeros(10),np.zeros(10),np.zeros(10),np.zeros(10),np.zeros(10),np.zeros(10),np.zeros(10),np.zeros(10),np.zeros(10),np.zeros(10)])
for i in range(10):
    for j in range(10):
        if((i+j)%2==0):
            x[i][j]=0
        else:
            x[i][j]=1
plt.imshow(x,cmap="gray")
plt.colorbar()

# %%
tra=fft2(x)
plt.imshow(abs(tra),cmap="gray")

# %%
k=np.zeros((20,20))
for i in range(20):
    for j in range(20):
        if((i+j)%2==0):
            k[i][j]=0
        else:
            k[i][j]=1
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")

# %%
k=np.zeros((50,50))
for i in range(50):
    for j in range(50):
        if((i+j)%2==0):
            k[i][j]=0
        else:
            k[i][j]=1
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")

# %% [markdown]
# ### Question 2 Done

# %% [markdown]
# ## Question 1

# %%
k=np.zeros((100,100))
f=20
t=f*10
for i in range(100):
    for j in range(100):
        k[i][j]=np.sin(2*np.pi*f*i*t)
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")

# %%
k=np.zeros((100,100))
f=10
t=f*10
for i in range(100):
    for j in range(100):
        k[i][j]=np.sin(2*np.pi*f*i*t)
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")

# %%
k=np.zeros((100,100))
f=1
t=1/f*10
for i in range(100):
    for j in range(100):
        k[i][j]=np.sin(2*np.pi*f*i*t)
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")

# %%
k=np.zeros((100,100))
fx=10
fy=20
t=1/fy*10
for i in range(100):
    for j in range(100):
        k[i][j]=np.sin(2*np.pi*fx*i*t+2*np.pi*fy*j*t)
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")

# %%
k=np.zeros((100,100))
fx=20
fy=20
t=1/fy*10
for i in range(100):
    for j in range(100):
        k[i][j]=np.sin(2*np.pi*fx*i*t+2*np.pi*fy*j*t)
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")

# %%
k=np.zeros((100,100))
fx=20
fy=20
t=1/fy*10
for i in range(100):
    for j in range(100):
        k[i][j]=np.sin(2*np.pi*fx*i*t+2*np.pi*fy*j*t)
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")

# %%
k=np.zeros((100,100))
fx=10
fy=10
t=1/fx*10
for i in range(100):
    for j in range(100):
        k[i][j]=20+np.cos(2*np.pi*(fy*j+fx*i)*t)
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")

# %%
k=np.zeros((100,100))
fx=10
fy=20
t=1/fy*10
for i in range(100):
    for j in range(100):
        k[i][j]=20+np.cos(2*np.pi*(fy*j+fx*i)*t)
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")

# %%
k=np.zeros((100,100))
fx=1
fy=20
t=1/fy*10
for i in range(100):
    for j in range(100):
        k[i][j]=20+np.cos(2*np.pi*(fy*j+fx*i)*t)
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")

# %%
k=np.zeros((100,100))
fx=20
fy=10
t=1/fx*10
for i in range(100):
    for j in range(100):
        k[i][j]=20+np.cos(2*np.pi*(fy*j+fx*i)*t)
plt.imshow(k,cmap="gray")
plt.colorbar()

# %%
tra1=fft2(k)
plt.imshow(abs(tra1),cmap="gray")
